# %%
import pandas as pd1

# %%
dataset =pd1.read_json('product_details.json')

# %%
dataset.head()
# Out:
#                                                  url                  title  \
# 0  https://www.nofrills.ca/en/roma-tomatoes/p/201...          Roma Tomatoes
# 1  https://www.nofrills.ca/en/mango/p/20059635001...                  Mango
# 2  https://www.nofrills.ca/en/cilantro/p/20091825...               Cilantro
# 3  https://www.nofrills.ca/en/garlic-bulbs-3-coun...  Garlic Bulbs, 3-count
# 4  https://www.nofrills.ca/en/ginger/p/2017903800...                 Ginger
#
#                       price                   mem_price  \
# 0             $0.79(est.)ea  Member Price not available
# 1                   $1.29ea  Member Price not available
# 2                   $0.99ea  Member Price not available
# 3                   $0.99ea  Member Price not available
# 4  $0.92(est.)ea$1.38(est.)  Member Price not available
#
#                   avg_weight pac_weight           weight_comp  \
# 0  Average weight is 0.12 KG      283 g  $6.59/ 1kg$2.99/ 1lb
# ...

# %%
dataset.shape
# Out:
# (48, 10)

# %%
dataset
# Out:
#                                                   url  \
# 0   https://www.nofrills.ca/en/roma-tomatoes/p/201...
# 1   https://www.nofrills.ca/en/mango/p/20059635001...
# 2   https://www.nofrills.ca/en/cilantro/p/20091825...
# 3   https://www.nofrills.ca/en/garlic-bulbs-3-coun...
# 4   https://www.nofrills.ca/en/ginger/p/2017903800...
# 5   https://www.nofrills.ca/en/colossal-garlic/p/2...
# 6   https://www.nofrills.ca/en/ritz-original-crack...
# 7   https://www.nofrills.ca/en/red-onions-3-lb-bag...
# 8   https://www.nofrills.ca/en/ritz-original-crack...
# 9   https://www.nofrills.ca/en/ah-caramel-the-orig...
# 10  https://www.nofrills.ca/en/smoked-black-forest...
# 11  https://www.nofrills.ca/en/jalapeno-peppers/p/...
# 12  https://www.nofrills.ca/en/almond-beverage-uns...
# 13  https://www.nofrills.ca/en/curly-parsley/p/200...
# 14  https://www.nofrills.ca/en/oat-beverage-origin...
# 15  https://www.nofrills.ca/en/ataulfo-mango/p/201...
# ...
